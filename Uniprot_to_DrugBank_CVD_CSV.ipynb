# %%
import xml.etree.ElementTree as ET

# %%
my_tree = ET.parse('/Users/josephramirez/full_database.xml')

# %%
root = my_tree.getroot() # get the root of the tree to be used in parsing
cardio_drugbank_id_list = []
associated_category_list = []
for child in root: #go through every child node
    for tag in child.findall('{http://www.drugbank.ca}categories'): #finds the categories tag
        for category in tag: #goes through first category tag
            for subcategory in category: #goes through second category tag
                if subcategory.tag == '{http://www.drugbank.ca}category': #checks the right namespace
                    if "Anticoag" in subcategory.text:
#                         associated_category_list.append(subcategory.text)
                        for tag in child.findall('{http://www.drugbank.ca}drugbank-id'): #searches for drugbank id
                            if 'primary' in tag.attrib: #gives only primary id 
                                drugbank_id = tag.text #sets drugbank id as the text
                                cardio_drugbank_id_list.append(drugbank_id)
                                break
                    if "Vasodilat" in subcategory.text:
#                         associated_category_list.append(subcategory.text)
                        for tag in child.findall('{http://www.drugbank.ca}drugbank-id'): #searches for drugbank id
                            if 'primary' in tag.attrib: #gives only primary id 
                                drugbank_id = tag.text #sets drugbank id as the text
                                cardio_drugbank_id_list.append(drugbank_id)
                                break
                    if "Antiplatelet" in subcategory.text:
#                         associated_category_list.append(subcategory.text)
                        for tag in child.findall('{http://www.drugbank.ca}drugbank-id'): #searches for drugbank id
                            if 'primary' in tag.attrib: #gives only primary id 
                                drugbank_id = tag.text #sets drugbank id as the text
                                cardio_drugbank_id_list.append(drugbank_id)
                                break
                    if "Angioten" in subcategory.text:
#                         associated_category_list.append(subcategory.text)
                        for tag in child.findall('{http://www.drugbank.ca}drugbank-id'): #searches for drugbank id
                            if 'primary' in tag.attrib: #gives only primary id 
                                drugbank_id = tag.text #sets drugbank id as the text
                                cardio_drugbank_id_list.append(drugbank_id)
                                break
                    if "Beta Block" in subcategory.text:
#                         associated_category_list.append(subcategory.text)
                        for tag in child.findall('{http://www.drugbank.ca}drugbank-id'): #searches for drugbank id
                            if 'primary' in tag.attrib: #gives only primary id 
                                drugbank_id = tag.text #sets drugbank id as the text
                                cardio_drugbank_id_list.append(drugbank_id)
                                break
                    if "Calcium Channel" in subcategory.text:
#                         associated_category_list.append(subcategory.text)
                        for tag in child.findall('{http://www.drugbank.ca}drugbank-id'): #searches for drugbank id
                            if 'primary' in tag.attrib: #gives only primary id 
                                drugbank_id = tag.text #sets drugbank id as the text
                                cardio_drugbank_id_list.append(drugbank_id)
                                break
                    if "ACE" in subcategory.text:
#                         associated_category_list.append(subcategory.text)
                        for tag in child.findall('{http://www.drugbank.ca}drugbank-id'): #searches for drugbank id
                            if 'primary' in tag.attrib: #gives only primary id 
                                drugbank_id = tag.text #sets drugbank id as the text
                                cardio_drugbank_id_list.append(drugbank_id)
                                break
                    if "Cholesterol" in subcategory.text:
#                         associated_category_list.append(subcategory.text)
                        for tag in child.findall('{http://www.drugbank.ca}drugbank-id'): #searches for drugbank id
                            if 'primary' in tag.attrib: #gives only primary id 
                                drugbank_id = tag.text #sets drugbank id as the text
                                cardio_drugbank_id_list.append(drugbank_id)
                                break
                    if "Digitalis" in subcategory.text:
#                         associated_category_list.append(subcategory.text)
                        for tag in child.findall('{http://www.drugbank.ca}drugbank-id'): #searches for drugbank id
                            if 'primary' in tag.attrib: #gives only primary id 
                                drugbank_id = tag.text #sets drugbank id as the text
                                cardio_drugbank_id_list.append(drugbank_id)
                                break
                    if "Diuretic" in subcategory.text:
#                         associated_category_list.append(subcategory.text)
                        for tag in child.findall('{http://www.drugbank.ca}drugbank-id'): #searches for drugbank id
                            if 'primary' in tag.attrib: #gives only primary id 
                                drugbank_id = tag.text #sets drugbank id as the text
                                cardio_drugbank_id_list.append(drugbank_id)
                                break

# %%
# get list of drugs from entire text file that harry sent
lines_of_target_drugs = []
total_drugs = []
with open('/Users/josephramirez/Downloads/Unified_Uniprot_to_DB.txt') as f:
    lines_of_target_drugs = f.readlines()

for item in lines_of_target_drugs:
    total_drugs.append(item.replace('\n', ''))
print(total_drugs)
# Out:
# ['DB00001', 'DB00002', 'DB00006', 'DB00009', 'DB00013', 'DB00015', 'DB00025', 'DB00028', 'DB00029', 'DB00030', 'DB00031', 'DB00035', 'DB00036', 'DB00041', 'DB00046', 'DB00047', 'DB00048', 'DB00054', 'DB00055', 'DB00061', 'DB00070', 'DB00071', 'DB00082', 'DB00083', 'DB00086', 'DB00091', 'DB00095', 'DB00098', 'DB00100', 'DB00102', 'DB00103', 'DB00104', 'DB00107', 'DB00108', 'DB00114', 'DB00115', 'DB00116', 'DB00118', 'DB00119', 'DB00120', 'DB00121', 'DB00122', 'DB00123', 'DB00125', 'DB00126', 'DB00127', 'DB00128', 'DB00129', 'DB00130', 'DB00131', 'DB00133', 'DB00134', 'DB00135', 'DB00136', 'DB00137', 'DB00139', 'DB00140', 'DB00141', 'DB00142', 'DB00143', 'DB00144', 'DB00145', 'DB00147', 'DB00148', 'DB00149', 'DB00150', 'DB00151', 'DB00152', 'DB00153', 'DB00154', 'DB00155', 'DB00156', 'DB00157', 'DB00158', 'DB00159', 'DB00160', 'DB00161', 'DB00162', 'DB00163', 'DB00165', 'DB00166', 'DB00167', 'DB00169', 'DB00170', 'DB00171', 'DB00172', 'DB00173', 'DB00174', 'DB00175', 'DB00178', 'DB0018
# ...

# %%
# compile all unique drugs that are present in both lists
import numpy as np
compiled_list_of_CVD_drugs = []
for item in cardio_drugbank_id_list:
    for drug in total_drugs:
        if item == drug:
            compiled_list_of_CVD_drugs.append(item)
            break
compiled_array_of_CVD_drugs = np.array(compiled_list_of_CVD_drugs)
compiled_array_of_CVD_drugs = np.unique(compiled_array_of_CVD_drugs)
B06228 DB06271 DB06406 DB06543 DB06605 DB06635 DB06695 DB06698 DB06712 DB06754 DB06779 DB06822 DB07278 DB08162 DB08496 DB08794 DB08813 DB08814 DB08816 DB08836 DB08838 DB08907 DB08931 DB08932 DB08949 DB09075 DB09089 DB09092 DB09154 DB09216 DB09220 DB09229 DB09231 DB09232 DB09236 DB09238 DB09258 DB09282 DB09283 DB09338 DB09401 DB09477 DB11166 DB11598 DB11827 DB12010 DB12364 DB12445 DB12598 DB12831 DB13149 DB13151 DB13166 DB13746 DB13919 DB13961 DB14500 DB14598 DB14600 DB15565'
}

data = urllib.parse.urlencode(params)
data = data.encode('utf-8')
req = urllib.request.Request(url, data)
with urllib.request.urlopen(req) as f:
    response = f.read()
match_db_to_uniprot = (response.decode('utf-8'))
print(match_db_to_uniprot)
# Out:
# From	To
# DB00001	P00734
# DB00006	P00734
# DB00006	P05164
# DB00009	P00747
# DB00009	P02671
# DB00009	P05121
# DB00009	Q03405
# DB00013	P00747
# DB00013	P05120
# DB00013	P05121
# DB00013	P05154
# DB00013	P14543
# DB00013	P39900
# DB00013	P98164
# DB00013	Q03405
# DB00013	Q9Y5Y6
# DB00015	P00747
# DB00015	P02671
# DB00015	P05121
# DB00029	P00747
# DB00029	P02671
# DB00029	P05121
# DB00031	P00747
# DB00031	P02671
# DB00031	P05120
# DB00031	P05121
# DB00031	P05452
# DB00031	P05787
# DB00031	P07355
# DB00031	P27797
# DB00031	P27824
# DB00031	Q03405
# DB00031	Q07954
# DB00054	P04004
# DB00054	P05106
# DB00054	P08514
# DB00054	P12318
# DB00054	P31994
# DB00055	P00451
# DB00055	P00734
# DB00055	P02776
# DB00055	P05121
# DB00055	P05154
# DB00055	P07204
# DB00055	P07225
# DB00055	P12259
# DB00055	P35237
# DB00055	Q9UNN8
# DB00086	P00747
# DB00086	P25116
# DB00086	P47712
# DB00178	P06276
# DB00178	P12821
# DB00178	P46059
# DB00178	P46663
# DB00178	Q16348
# DB00203	O15439
# DB00203	O15440
# ...

# %%
match_db_to_uniprot = match_db_to_uniprot.split()

# %%
print(match_db_to_uniprot)
match_db_to_uniprot.pop(0)
match_db_to_uniprot.pop(0)
print(len(match_db_to_uniprot))
print(match_db_to_uniprot[0]) # final entry
# Out:
# ['From', 'To', 'DB00001', 'P00734', 'DB00006', 'P00734', 'DB00006', 'P05164', 'DB00009', 'P00747', 'DB00009', 'P02671', 'DB00009', 'P05121', 'DB00009', 'Q03405', 'DB00013', 'P00747', 'DB00013', 'P05120', 'DB00013', 'P05121', 'DB00013', 'P05154', 'DB00013', 'P14543', 'DB00013', 'P39900', 'DB00013', 'P98164', 'DB00013', 'Q03405', 'DB00013', 'Q9Y5Y6', 'DB00015', 'P00747', 'DB00015', 'P02671', 'DB00015', 'P05121', 'DB00029', 'P00747', 'DB00029', 'P02671', 'DB00029', 'P05121', 'DB00031', 'P00747', 'DB00031', 'P02671', 'DB00031', 'P05120', 'DB00031', 'P05121', 'DB00031', 'P05452', 'DB00031', 'P05787', 'DB00031', 'P07355', 'DB00031', 'P27797', 'DB00031', 'P27824', 'DB00031', 'Q03405', 'DB00031', 'Q07954', 'DB00054', 'P04004', 'DB00054', 'P05106', 'DB00054', 'P08514', 'DB00054', 'P12318', 'DB00054', 'P31994', 'DB00055', 'P00451', 'DB00055', 'P00734', 'DB00055', 'P02776', 'DB00055', 'P05121', 'DB00055', 'P05154', 'DB00055', 'P07204', 'DB00055', 'P07225', 'DB00055', 'P12259', 'DB00055', 'P3523
# ...

# %%
# start edits here [0:4234]
# for testing
for index in range(len(match_db_to_uniprot) - 1):
    if "DB" not in match_db_to_uniprot[index]:
        continue
    else:
        print(match_db_to_uniprot[index + 1], "HAS_RELATED_DRUG", match_db_to_uniprot[index])

#     print(item)
# type(match_db_to_uniprot[0])
# animal = 'dog'
# print (animal + 1)
# Out:
# P00734 HAS_RELATED_DRUG DB00001
# P00734 HAS_RELATED_DRUG DB00006
# P05164 HAS_RELATED_DRUG DB00006
# P00747 HAS_RELATED_DRUG DB00009
# P02671 HAS_RELATED_DRUG DB00009
# P05121 HAS_RELATED_DRUG DB00009
# Q03405 HAS_RELATED_DRUG DB00009
# P00747 HAS_RELATED_DRUG DB00013
# P05120 HAS_RELATED_DRUG DB00013
# P05121 HAS_RELATED_DRUG DB00013
# P05154 HAS_RELATED_DRUG DB00013
# P14543 HAS_RELATED_DRUG DB00013
# P39900 HAS_RELATED_DRUG DB00013
# P98164 HAS_RELATED_DRUG DB00013
# Q03405 HAS_RELATED_DRUG DB00013
# Q9Y5Y6 HAS_RELATED_DRUG DB00013
# P00747 HAS_RELATED_DRUG DB00015
# P02671 HAS_RELATED_DRUG DB00015
# P05121 HAS_RELATED_DRUG DB00015
# P00747 HAS_RELATED_DRUG DB00029
# P02671 HAS_RELATED_DRUG DB00029
# P05121 HAS_RELATED_DRUG DB00029
# P00747 HAS_RELATED_DRUG DB00031
# P02671 HAS_RELATED_DRUG DB00031
# P05120 HAS_RELATED_DRUG DB00031
# P05121 HAS_RELATED_DRUG DB00031
# P05452 HAS_RELATED_DRUG DB00031
# P05787 HAS_RELATED_DRUG DB00031
# P07355 HAS_RELATED_DRUG DB00031
# ...

# %%
import csv 
with open ('/Users/josephramirez/Desktop/edge_list.csv', 'w', newline='') as f:
    csvwriter = csv.writer(f) # set the csv writer
    csvwriter.writerow(["UNIPROT_ID", "RELATIONSHIP", "DRUGBANK_ID"]) # write the heading columns
    for index in range(len(match_db_to_uniprot) - 1): 
        if "DB" not in match_db_to_uniprot[index]:
            continue
        else:
            csvwriter.writerow([match_db_to_uniprot[index + 1], "HAS_RELATED_DRUG", match_db_to_uniprot[index]]) 
            # print the uniprot id, relationship, and drugbank id in that order
